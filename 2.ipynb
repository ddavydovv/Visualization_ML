# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
from itables import init_notebook_mode

# %%
Energy1=pd.read_csv('Plant_1_Generation_Data.csv')
Energy2=pd.read_csv('Plant_2_Generation_Data.csv')

# %%
gen=pd.concat ([Energy1,Energy2])

# %%
Pogoda1=pd.read_csv('Plant_1_Weather_Sensor_Data.csv')
Pogoda2=pd.read_csv('Plant_2_Weather_Sensor_Data.csv')

# %%
Pog=pd.concat ([Pogoda1,Pogoda2])

# %%
Pog.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6441 entries, 0 to 3258
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   DATE_TIME            6441 non-null   object
#  1   PLANT_ID             6441 non-null   int64
#  2   SOURCE_KEY           6441 non-null   object
#  3   AMBIENT_TEMPERATURE  6441 non-null   float64
#  4   MODULE_TEMPERATURE   6441 non-null   float64
#  5   IRRADIATION          6441 non-null   float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 352.2+ KB

# %%
gen.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 136476 entries, 0 to 67697
# Data columns (total 7 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   DATE_TIME    136476 non-null  object
#  1   PLANT_ID     136476 non-null  int64
#  2   SOURCE_KEY   136476 non-null  object
#  3   DC_POWER     136476 non-null  float64
#  4   AC_POWER     136476 non-null  float64
#  5   DAILY_YIELD  136476 non-null  float64
#  6   TOTAL_YIELD  136476 non-null  float64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 8.3+ MB

# %%
Pog
# Out:
#                 DATE_TIME  PLANT_ID       SOURCE_KEY  AMBIENT_TEMPERATURE  \
# 0     2020-05-15 00:00:00   4135001  HmiyD2TTLFNqkNe            25.184316
# 1     2020-05-15 00:15:00   4135001  HmiyD2TTLFNqkNe            25.084589
# 2     2020-05-15 00:30:00   4135001  HmiyD2TTLFNqkNe            24.935753
# 3     2020-05-15 00:45:00   4135001  HmiyD2TTLFNqkNe            24.846130
# 4     2020-05-15 01:00:00   4135001  HmiyD2TTLFNqkNe            24.621525
# ...                   ...       ...              ...                  ...
# 3254  2020-06-17 22:45:00   4136001  iq8k7ZNt4Mwm3w0            23.511703
# 3255  2020-06-17 23:00:00   4136001  iq8k7ZNt4Mwm3w0            23.482282
# 3256  2020-06-17 23:15:00   4136001  iq8k7ZNt4Mwm3w0            23.354743
# 3257  2020-06-17 23:30:00   4136001  iq8k7ZNt4Mwm3w0            23.291048
# 3258  2020-06-17 23:45:00   4136001  iq8k7ZNt4Mwm3w0            23.202871
#
#       MODULE_TEMPERATURE  IRRADIATION
# 0              22.857507          0.0
# ...

# %%
gen
# Out:
#                  DATE_TIME  PLANT_ID       SOURCE_KEY  DC_POWER  AC_POWER  \
# 0         15-05-2020 00:00   4135001  1BY6WEcLGh8j5v7       0.0       0.0
# 1         15-05-2020 00:00   4135001  1IF53ai7Xc0U56Y       0.0       0.0
# 2         15-05-2020 00:00   4135001  3PZuoBAID5Wc2HD       0.0       0.0
# 3         15-05-2020 00:00   4135001  7JYdWkrLSPkdwr4       0.0       0.0
# 4         15-05-2020 00:00   4135001  McdE0feGgRqW7Ca       0.0       0.0
# ...                    ...       ...              ...       ...       ...
# 67693  2020-06-17 23:45:00   4136001  q49J1IKaHRwDQnt       0.0       0.0
# 67694  2020-06-17 23:45:00   4136001  rrq4fwE8jgrTyWY       0.0       0.0
# 67695  2020-06-17 23:45:00   4136001  vOuJvMaM2sgwLmb       0.0       0.0
# 67696  2020-06-17 23:45:00   4136001  xMbIugepa2P7lBB       0.0       0.0
# 67697  2020-06-17 23:45:00   4136001  xoJJ8DcxJEcupym       0.0       0.0
#
#        DAILY_YIELD  TOTAL_YIELD
# 0              0.0    6259559.0
# ...

# %%
Pog.groupby('PLANT_ID')['SOURCE_KEY'].nunique()
# Out:
# PLANT_ID
# 4135001    1
# 4136001    1
# Name: SOURCE_KEY, dtype: int64

# %%
gen.groupby('PLANT_ID')['SOURCE_KEY'].nunique()
# Out:
# PLANT_ID
# 4135001    22
# 4136001    22
# Name: SOURCE_KEY, dtype: int64

# %%
sns.catplot(data=Pog, x="PLANT_ID", y="AMBIENT_TEMPERATURE", kind='violin')
# Out:
# C:\Users\Дмитрий\Desktop\MachineLearning\venv\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(data=Pog, x="PLANT_ID", y="MODULE_TEMPERATURE", kind='violin')
# Out:
# C:\Users\Дмитрий\Desktop\MachineLearning\venv\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(data=Pog, x="PLANT_ID", y="IRRADIATION", kind='violin')
# Out:
# C:\Users\Дмитрий\Desktop\MachineLearning\venv\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
